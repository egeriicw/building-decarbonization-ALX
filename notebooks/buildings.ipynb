# %%
# Standard Analysis Libraries
import pandas as pd
import geopandas as gpd
import matplotlib
import seaborn as sbnconda
import descartes

# %%
spatial_input_data = './../data/input/spatial/'

# %%
gdf = gpd.read_file(spatial_input_data + 'Building.shp')
gdf.plot()
# Out:
# <AxesSubplot:>
